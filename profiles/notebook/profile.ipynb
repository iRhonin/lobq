# %% [markdown]
# # Profile

# %% [markdown]
# ### Importing things and profile function

# %%
import pandas as pd
import matplotlib.pyplot as plt

from profiles import profile

# %% [markdown]
# ### Profiling for Queue size of 10

# %%
result = profile(q_size=10, data_size=1500, levels=5, runs=100)
result['scaled_time'] = result['time'] / min(result['time'])
result = result.sort_values('scaled_time')
result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-3b158a80d064> in <module>
# ----> 1 result = profile(q_size=10, data_size=1500, levels=5, runs=100)
#       2 result['scaled_time'] = result['time'] / min(result['time'])
#       3 result = result.sort_values('scaled_time')
#       4 result
#
# ~/workspace/lobq/profiles/__init__.py in profile(q_size, data_size, levels, runs)
#     100     for type_, fn in types:
#     101         data = generate_data()
# --> 102         res = profile_func(fn, type_, q_size, data_size, levels, runs)
#     103         results = results.append(res, ignore_index=True)
#     104
#
# ~/workspace/lobq/profiles/__init__.py in profile_func(fn, type_, q_size, data_size, levels, runs)
#      30         type_=[type_],
#      31         time=[time],
# ---> 32         time_per_loop=[time / data_sizeprofile(10, 1500, 5, 100)],
#      33         q_size=q_size,
#      34         data_size=[data_size],
#
# NameError: name 'data_sizeprofile' is not defined

# %%
ax = result.plot(kind='barh', x='type_', y='scaled_time', color="slategray", fontsize=13, figsize=(9,5))
ax.set_alpha(0.1)
ax.set_title("Queue Size: 10", fontsize=18);
ax.set_xlabel("CPU Time", fontsize=18);
ax.set_ylabel("Implemention", fontsize=18);
ax.set_xticks([i*5 for i in range(10)])

for i in ax.patches:
    ax.text(
        i.get_width()+.2, i.get_y()+.31, 
        f'{round((i.get_width()), 2)}x', 
        fontsize=15, color='dimgrey',
    )
    
ax.invert_yaxis()

# %% [markdown]
# ### Profiling for Queue size of 200

# %%
result = profile(200, 1500, 5, 100)
result['scaled_time'] = result['time'] / min(result['time'])
result = result.sort_values('scaled_time')
result
# Out:
#            type_      time  time_per_loop  q_size  data_size  levels  runs  \
# 0          C API  0.000242   1.611077e-07     200       1500       5   100
# 2         Cython  0.000523   3.488233e-07     200       1500       5   100
# 4          Numpy  0.000939   6.256998e-07     200       1500       5   100
# 1    Pure Python  0.001003   6.684370e-07     200       1500       5   100
# 3  Builtin Queue  0.008598   5.732310e-06     200       1500       5   100
#
#    scaled_time
# 0     1.000000
# 2     2.165155
# 4     3.883735
# 1     4.149006
# 3    35.580601

# %%
ax = result.plot(kind='barh', x='type_', y='scaled_time', color="slategray", fontsize=13, figsize=(9,5))
ax.set_alpha(0.1)
ax.set_title("Queue Size:200", fontsize=18);
ax.set_xlabel("CPU Time", fontsize=18);
ax.set_ylabel("Implemention", fontsize=18);
ax.set_xticks([i*5 for i in range(10)])

for i in ax.patches:
    ax.text(
        i.get_width()+.2, i.get_y()+.31, 
        f'{round((i.get_width()), 2)}x', 
        fontsize=15, color='dimgrey',
    )
    
ax.invert_yaxis()
